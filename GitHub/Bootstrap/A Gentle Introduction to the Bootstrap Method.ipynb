# %% [markdown]
# ### basic introduction to the bootstrap method

# %%
print 'https://machinelearningmastery.com/a-gentle-introduction-to-the-bootstrap-method/'
# Out:
# https://machinelearningmastery.com/a-gentle-introduction-to-the-bootstrap-method/

# %% [markdown]
# ### seeing-theory and data visualization

# %%
print 'https://seeing-theory.brown.edu/frequentist-inference/index.html#section1'
# Out:
# https://seeing-theory.brown.edu/frequentist-inference/index.html#section1

# %% [markdown]
# ### Probability Distributions in Python

# %%
print 'https://www.datacamp.com/community/tutorials/probability-distributions-python'
# Out:
# https://www.datacamp.com/community/tutorials/probability-distributions-python

# %%
from scipy.stats import uniform, norm, gamma, expon, poisson, binom, bernoulli

# %% [markdown]
# ### Bootstrap API

# %%
# Uniform Distribution

# data sample
n = 50
start = 10
width = 20

# random numbers from uniform distribution
data_uniform = uniform.rvs(size=n, loc = start, scale=width)

# prepare bootstrap sample
boot = resample(data_uniform, replace=True, n_samples=20, random_state=1)
print('Bootstrap Sample: %s' % boot)
# Out:
# Bootstrap Sample: [26.04241532 15.02971757 29.44866021 25.97245881 10.25570779 23.89441596
#  22.28437399 11.14680604 18.09980371 24.9574558  29.95550567 29.44866021
#  11.21491488 24.30537493 27.68949524 18.89263516 12.74718604 26.04241532
#  22.7830969  12.74718604]

# %%
# out of bag observations
oob = [x for x in data_uniform if x not in boot]
print('OOB Sample: %s' % oob)
# Out:
# OOB Sample: [20.83028954168533, 21.272464148675986, 13.554628906561035, 10.78547409918932, 24.053311739715575, 24.74592349685623, 27.23555928776068, 23.948454240838274, 18.541868932897557, 26.185488791285227, 18.991712534918136, 13.849998681450606, 14.269022646014458, 18.32690569364095, 15.693751982151095, 24.041989817049984, 20.022944409198182, 29.52457236418593, 15.285074571950592, 10.3018013194254, 23.484393841702907, 27.077913116014766, 23.174014712005558, 29.021393620996907, 12.749150891517882, 12.282087191433078, 25.605297308324445, 17.739233569316454, 29.0045354941449, 28.699724084774367, 28.868797792041804, 18.365571785753623, 10.09041161486289]

# %%
ax = sns.distplot(data_uniform,
                  bins = 100,
                  kde = True,
                  color = 'skyblue',
                  hist_kws = {"linewidth": 15, 'alpha':1})
ax.set(xlabel='Uniform Distribution ', ylabel = 'Frequency')
# Out:
# [Text(0,0.5,'Frequency'), Text(0.5,0,'Uniform Distribution ')]

# %%
# Normal Distribution

# data sample
n = 50

# generate random numbers from N(0,1)
data_norm = norm.rvs(size=n, loc=0, scale=1)

# prepare bootstrap sample
boot = resample(data_norm, replace=True, n_samples=20, random_state=1)
print('Bootstrap Sample: %s' % boot)
# Out:
# Bootstrap Sample: [ 1.33012812  1.29675138  1.42522129 -1.10844138  0.02300335  1.77983208
#  -1.80038515 -0.71280023  0.35436502  0.8938972  -0.05719061  1.42522129
#  -0.11208477  1.47798525  1.26392317 -0.08998056 -1.48223287  1.33012812
#  -0.06408672 -1.48223287]

# %%
# out of bag observations
oob = [x for x in data_norm if x not in boot]
print('OOB Sample: %s' % oob)
# Out:
# OOB Sample: [-0.9720071439842608, -0.3420110080579223, 0.29832453680793103, 1.1869685968780996, -0.9525046076539482, 1.4035558448825, -2.3091810174388687, -1.4774137783096601, -0.8825027316390976, -0.11986007446693966, 0.336540685884886, -0.38916717808864976, 0.20897281510787527, -0.6712725356677703, 0.6639783539748192, -0.31571904543616097, 1.607363442753924, -0.2487008090499651, 2.1730249977048417, -1.3461558085728877, -1.618022235966923, 0.5094932830019873, 0.07672079936763156, 0.12981764826359615, -0.8990813204384615, -0.21458899930925765, -0.6052232161078168, 0.35582581140177694, -1.8722858585440167, 0.6560407864803892, 0.1041795550679607, -1.690458195577921, -0.18517950362469135]

# %%
import seaborn as sns

# settings for seaborn plotting style
sns.set(color_codes=True)

# settings for seaborn plot sizes
sns.set(rc = {'figure.figsize':(5,5)})
ax = sns.distplot(data_norm,
                  bins = 100,
                  color = 'skyblue',
                  kde = True, #with/without skyblue lines
                  hist_kws = {"linewidth": 15, 'alpha':1})
ax.set(xlabel = 'Normal Distribution', ylabel = 'Frequency')
# Out:
# [Text(0,0.5,'Frequency'), Text(0.5,0,'Normal Distribution')]

# %%
# Gamma Distribution

# data sample
n = 100

data_gamma = gamma.rvs(a=5, size=n)

# prepare bootstrap sample
boot = resample(data_gamma, replace=True, n_samples=20, random_state=1)
print('Bootstrap Sample: %s' % boot)
# Out:
# Bootstrap Sample: [ 5.91511996  2.95617236  3.68699101  4.34720136 10.25367277  7.053423
#   4.83717428  5.89897485  1.87754672  4.59579776  4.28546903  7.30931245
#   2.56770941  1.6541602   5.73826394  1.58159604  5.77320859  5.8342923
#   4.34844213  5.34617592]

# %%
# out of bag observations
oob = [x for x in data_gamma if x not in boot]
print('OOB Sample: %s' % oob)
# Out:
# OOB Sample: [6.086735431369069, 3.752249655467517, 9.804754363543662, 3.5789135176714346, 8.963277741293176, 10.532600657056884, 1.8525091097989321, 8.180674303016128, 3.1050354058682155, 3.9849092040263803, 5.718987988221795, 3.6344135982366534, 4.897724942425019, 3.1060475471418583, 7.068620936380336, 9.145737791355963, 3.6412104813738218, 5.856540731521353, 5.841953812170075, 3.6672638617015174, 2.9886453553818026, 9.632755298402948, 9.185139500391902, 4.036554823797102, 5.791492500923092, 8.993185758589673, 4.857611493450906, 4.936771831147382, 4.874615353100128, 3.357737116963584, 4.314180175330222, 4.478372803604389, 7.202881629812228, 1.9047249285006336, 7.617552705845491, 7.27830699391006, 7.247621864373124, 7.281875845956407, 4.152515657429624, 6.59712936633585, 2.4560020806369773, 4.5858688706124, 2.664756413875158, 9.363687311414825, 4.045420829528973, 1.7286696661215626, 7.170156761156984, 4.1175657455607375, 14.254874747389607, 5.153452487683676, 7.117257115154023, 5.435
# ...

# %%
ax = sns.distplot(data_gamma,
                  kde = True,
                  bins = 100,
                  color = 'skyblue',
                  hist_kws = {"linewidth": 15, 'alpha':1})
ax.set(xlabel = 'Gamma Distribution', ylabel = 'Frequency')
# Out:
# [Text(0,0.5,'Frequency'), Text(0.5,0,'Gamma Distribution')]

# %%
# Exponential Distribution

# data sample
n = 100

data_expon = expon.rvs(scale=1, loc=0, size=n)

# prepare bootstrap sample
boot = resample(data_expon, replace=True, n_samples=20, random_state=1)
print('Bootstrap Sample: %s' % boot)
# Out:
# Bootstrap Sample: [1.04963134 1.13366565 0.30295721 3.11483891 0.08937828 1.02643502
#  0.74008068 3.7759292  1.39943121 0.6159107  0.37423912 2.83947821
#  0.00840753 1.85719528 0.63065084 2.32619121 1.36323917 0.32341185
#  0.13365153 0.61355942]

# %%
# out of bag observations
oob = [x for x in data_expon if x not in boot]
print('OOB Sample: %s' % oob)
# Out:
# OOB Sample: [0.03129266128141496, 0.23149029918129876, 0.3200636849700971, 0.41497019969339566, 1.59887031259648, 0.7338997840525169, 0.7368131463106173, 0.9430930625189285, 0.6843556109154945, 0.06658695415755285, 0.657629319221925, 0.8012758742049211, 0.4377839375162636, 1.6950641945507727, 2.918814728205882, 0.8248094361554903, 1.7637950421871607, 1.5224616256750445, 1.4460529166934493, 0.3108143954615603, 0.9393621285412483, 0.40936601677166956, 0.20447010851724726, 1.0742158075905475, 1.6202302173933687, 0.11889513445828756, 1.9172521904729956, 0.06366700362679693, 1.1274375032740196, 0.18049238843979923, 0.11285817202675817, 0.5255270452446033, 0.8685385166490565, 0.7590327483173314, 1.8748191251393767, 0.5343447882192122, 0.5043320720077112, 0.8089429045052541, 1.2181888745619693, 0.43134513894175885, 1.7820629434334962, 0.1825963098073283, 0.5967050123205985, 0.5870981915256311, 0.4163329212931983, 0.5469220109915037, 0.63371959623886, 1.083966756114259, 0.20978367497594105, 
# ...

# %%
ax = sns.distplot(data_expon,
                  kde = True,
                  bins = 100,
                  color = 'skyblue',
                  hist_kws = {"linewidth": 15, 'alpha':1})
ax.set(xlabel = 'Exponential Distribution', ylabel = 'Frequency')
# Out:
# [Text(0,0.5,'Frequency'), Text(0.5,0,'Exponential Distribution')]

# %%
#Poisson Distribution

# data sample
n = 100

data_poisson = poisson.rvs(mu=3, size=n)

# prepare bootstrap sample
boot = resample(data_poisson, replace=True, n_samples=20, random_state=1)
print('Bootstrap Sample: %s' % boot)
# Out:
# Bootstrap Sample: [3 2 3 4 4 4 2 2 2 2 1 3 3 4 2 3 2 4 7 2]

# %%
# out of bag observations
oob = [x for x in data_poisson if x not in boot]
print('OOB Sample: %s' % oob)
# Out:
# OOB Sample: [0, 9, 6, 0, 5, 6, 6, 0, 0, 0, 5, 6, 0, 5]

# %%
ax = sns.distplot(data_poisson,
                  kde = True,
                  bins = 100,
                  color = 'skyblue',
                  hist_kws = {"linewidth": 15, 'alpha':1})
ax.set(xlabel = 'Poisson Distribution', ylabel = 'Frequency')
# Out:
# [Text(0,0.5,'Frequency'), Text(0.5,0,'Poisson Distribution')]

# %%
#Binomial Distribution

# data sample
n = 100

data_binom = binom.rvs(n=10,p=0.8,size=n)

# prepare bootstrap sample
boot = resample(data_binom, replace=True, n_samples=20, random_state=1)
print('Bootstrap Sample: %s' % boot)
# Out:
# Bootstrap Sample: [10  6 10  7  7  7  7 10  7  9  8  8  8  7  9  8  9  7  8  6]

# %%
# out of bag observations
oob = [x for x in data_binom if x not in boot]
print('OOB Sample: %s' % oob)
# Out:
# OOB Sample: [4, 5, 4, 5]

# %%
ax = sns.distplot(data_binom,
                  kde = True,
                  bins = 100,
                  color = 'skyblue',
                  hist_kws = {"linewidth": 15, 'alpha':1})
ax.set(xlabel = 'Binomial Distribution', ylabel = 'Frequency')
# Out:
# [Text(0,0.5,'Frequency'), Text(0.5,0,'Binomial Distribution')]

# %%
#Bernoulli Distribution

# data sample
n = 100

data_bern = bernoulli.rvs(size=n, p=0.6)

# prepare bootstrap sample
boot = resample(data_bern, replace=True, n_samples=20, random_state=1)
print('Bootstrap Sample: %s' % boot)
# Out:
# Bootstrap Sample: [1 0 0 1 1 1 0 1 1 1 0 0 0 0 1 0 1 1 1 0]

# %%
# out of bag observations
oob = [x for x in data_bern if x not in boot]
print('OOB Sample: %s' % oob)
# Out:
# OOB Sample: []

# %%
ax = sns.distplot(data_bern,
                  kde = True,
                  bins = 100,
                  color = 'skyblue',
                  hist_kws = {"linewidth": 15, 'alpha':1})
ax.set(xlabel = 'Bernoulli Distribution', ylabel = 'Frequency')
# Out:
# [Text(0,0.5,'Frequency'), Text(0.5,0,'Bernoulli Distribution')]
