# %%
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
iris = datasets.load_iris()

x = pd.DataFrame(iris['data'], columns=iris['feature_names'])
#print("target: " + str(iris['target']))
print("target_names: " + str(iris['target_names']))
#print("feature_names: " + str(iris['feature_names']))

y = pd.DataFrame(iris['target'], columns=['target'])
iris_data = pd.concat([x,y], axis=1)
iris_data.head(3)
# Out:
# target_names: ['setosa' 'versicolor' 'virginica']
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
#
#    target
# 0       0
# 1       0
# 2       0

# %%
#print iris['feature_names']
print iris['target_names']
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
target_name = {
    0:'setosa',
    1:'versicolor',
    2:'virginica'
}
target_name
# Out:
# {0: 'setosa', 1: 'versicolor', 2: 'virginica'}

# %%
iris_data['target_name'] = iris_data['target'].map(target_name)
iris_data = iris_data[(iris_data['target_name'] == 'setosa')|(iris_data['target_name'] == 'versicolor')]
iris_data = iris_data[['sepal length (cm)','petal length (cm)','target_name']]
iris_data.head(5)
# Out:
#    sepal length (cm)  petal length (cm) target_name
# 0                5.1                1.4      setosa
# 1                4.9                1.4      setosa
# 2                4.7                1.3      setosa
# 3                4.6                1.5      setosa
# 4                5.0                1.4      setosa

# %%
target_class = {
    'setosa':1,
    'versicolor':-1
}
target_class
# Out:
# {'setosa': 1, 'versicolor': -1}

# %%
iris_data['target_class'] = iris_data['target_name'].map(target_class)

# %%
iris_data.head(5)
# Out:
#    sepal length (cm)  petal length (cm) target_name  target_class
# 0                5.1                1.4      setosa             1
# 1                4.9                1.4      setosa             1
# 2                4.7                1.3      setosa             1
# 3                4.6                1.5      setosa             1
# 4                5.0                1.4      setosa             1

# %%
del iris_data['target_name']

# %%
# setosa
iris_data[(iris_data['target_class'] == 1)]
# Out:
#     sepal length (cm)  petal length (cm)  target_class
# 0                 5.1                1.4             1
# 1                 4.9                1.4             1
# 2                 4.7                1.3             1
# 3                 4.6                1.5             1
# 4                 5.0                1.4             1
# 5                 5.4                1.7             1
# 6                 4.6                1.4             1
# 7                 5.0                1.5             1
# 8                 4.4                1.4             1
# 9                 4.9                1.5             1
# 10                5.4                1.5             1
# 11                4.8                1.6             1
# 12                4.8                1.4             1
# 13                4.3                1.1             1
# 14                5.8                1.2             1
# 15                5.7                1.5             1
# 16                5.4                1.3             1
# 17                5.1                1.4             1
# 18                5.7                1.7             1
# 19                5.1                1.5             1
# 20                5.4                1.7             1
# 21                5.1                1.5             1
# 22                4.6                1.0             1
# 23                5.1                1.7             1
# 24                4.8                1.9             1
# 25                5.0                1.6             1
# 26                5.0                1.6             1
# 27                5.2                1.5             1
# 28                5.2                1.4             1
# 29                4.7                1.6             1
# 30                4.8                1.6             1
# 31                5.4                1.5             1
# 32                5.2                1.5             1
# 33                5.5                1.4             1
# 34                4.9                1.5             1
# 35                5.0                1.2             1
# 36                5.5                1.3             1
# 37                4.9                1.5             1
# 38                4.4                1.3             1
# 39                5.1                1.5             1
# 40                5.0                1.3             1
# 41                4.5                1.3             1
# 42                4.4                1.3             1
# 43                5.0                1.6             1
# 44                5.1                1.9             1
# 45                4.8                1.4             1
# 46                5.1                1.6             1
# 47                4.6                1.4             1
# 48                5.3                1.5             1
# 49                5.0                1.4             1

# %%
# versicolor
iris_data[(iris_data['target_class'] == -1)]
# Out:
#     sepal length (cm)  petal length (cm)  target_class
# 50                7.0                4.7            -1
# 51                6.4                4.5            -1
# 52                6.9                4.9            -1
# 53                5.5                4.0            -1
# 54                6.5                4.6            -1
# 55                5.7                4.5            -1
# 56                6.3                4.7            -1
# 57                4.9                3.3            -1
# 58                6.6                4.6            -1
# 59                5.2                3.9            -1
# 60                5.0                3.5            -1
# 61                5.9                4.2            -1
# 62                6.0                4.0            -1
# 63                6.1                4.7            -1
# 64                5.6                3.6            -1
# 65                6.7                4.4            -1
# 66                5.6                4.5            -1
# 67                5.8                4.1            -1
# 68                6.2                4.5            -1
# 69                5.6                3.9            -1
# 70                5.9                4.8            -1
# 71                6.1                4.0            -1
# 72                6.3                4.9            -1
# 73                6.1                4.7            -1
# 74                6.4                4.3            -1
# 75                6.6                4.4            -1
# 76                6.8                4.8            -1
# 77                6.7                5.0            -1
# 78                6.0                4.5            -1
# 79                5.7                3.5            -1
# 80                5.5                3.8            -1
# 81                5.5                3.7            -1
# 82                5.8                3.9            -1
# 83                6.0                5.1            -1
# 84                5.4                4.5            -1
# 85                6.0                4.5            -1
# 86                6.7                4.7            -1
# 87                6.3                4.4            -1
# 88                5.6                4.1            -1
# 89                5.5                4.0            -1
# 90                5.5                4.4            -1
# 91                6.1                4.6            -1
# 92                5.8                4.0            -1
# 93                5.0                3.3            -1
# 94                5.6                4.2            -1
# 95                5.7                4.2            -1
# 96                5.7                4.2            -1
# 97                6.2                4.3            -1
# 98                5.1                3.0            -1
# 99                5.7                4.1            -1

# %%
# Activation function
def sign(z):
    if z > 0:
        return 1
    else:
        return -1

# %%
w = np.array([0.,0.,0.])
x,y = np.concatenate((np.array([1.]), np.array(iris_data.iloc[0])[:2])), np.array(iris_data.iloc[0])[2]
print np.array([1.]);
print iris_data.iloc[0];
print x,y
# Out:
# [1.]
# sepal length (cm)    5.1
# petal length (cm)    1.4
# target_class         1.0
# Name: 0, dtype: float64
# [1.  5.1 1.4] 1.0

# %%
#開始w=[0,0,0]所以 0*1 + 0*花萼的長度 + 0*花瓣的長度 = 0 ，因為≤0 都會預測成versicolor(-1類)
w = np.array([0.,0.,0.]) 
error = 1
iterator = 0

while error != 0:
    error = 0

    for i in range(len(iris_data)):

        # x的資料都加上x0=1 (x0永遠是1)
        x = np.concatenate((np.array([1.]), np.array(iris_data.iloc[i])[:2]))
        y = np.array(iris_data.iloc[i])[2]

        # 指預測失敗時
        print("sign: " + str(sign(np.dot(w,x))) + ", y: " + str(y) + ", x: " + str(x))
        if sign(np.dot(w,x)) != y:
            print("iterator: " +str(iterator))
            iterator += 1
            
            #紀錄沒有錯誤分類的話就停止
            error += 1

            sns.lmplot('sepal length (cm)','petal length (cm)',data=iris_data, fit_reg=False, hue ='target_class')
            
            # 前一個Decision boundary 的法向量
            if w[1] != 0:
                x_last_decision_boundary = np.linspace(0,w[1])
                y_last_decision_boundary = (w[2]/w[1])*x_last_decision_boundary
                plt.plot(x_last_decision_boundary, y_last_decision_boundary,'c--')

            w += y*x
            print("x: " + str(x))            
            print("w: " + str(w))


            # x向量 
            x_vector = np.linspace(0,x[1])
            y_vector = (x[2]/x[1])*x_vector
            plt.plot(x_vector, y_vector,'b')

            # Decision boundary 的方向向量
            x_decision_boundary = np.linspace(-0.5,7)
            y_decision_boundary = (-w[1]/w[2])*x_decision_boundary - (w[0]/w[2])
            plt.plot(x_decision_boundary, y_decision_boundary,'r')

            # Decision boundary 的法向量
            x_decision_boundary_normal_vector = np.linspace(0,w[1])
            y_decision_boundary_normal_vector = (w[2]/w[1])*x_decision_boundary_normal_vector
            plt.plot(x_decision_boundary_normal_vector, y_decision_boundary_normal_vector,'g')
            plt.xlim(-0.5,7.5)
            plt.ylim(5,-3)
            plt.show()
# Out:
# sign: -1, y: 1.0, x: [1.  5.1 1.4]
# iterator: 0
# x: [1.  5.1 1.4]
# w: [1.  5.1 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.3]
# sign: 1, y: 1.0, x: [1.  4.6 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.  1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  4.3 1.1]
# sign: 1, y: 1.0, x: [1.  5.8 1.2]
# sign: 1, y: 1.0, x: [1.  5.7 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.4]
# sign: 1, y: 1.0, x: [1.  5.7 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  4.6 1. ]
# sign: 1, y: 1.0, x: [1.  5.1 1.7]
# sign: 1, y: 1.0, x: [1.  4.8 1.9]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.5 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.2]
# sign: 1, y: 1.0, x: [1.  5.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.3]
# sign: 1, y: 1.0, x: [1.  4.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.1 1.9]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  5.1 1.6]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.3 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: 1, y: -1.0, x: [1.  7.  4.7]
# iterator: 1
# x: [1.  7.  4.7]
# w: [ 0.  -1.9 -3.3]
# sign: -1, y: -1.0, x: [1.  6.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.9 4.9]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  6.5 4.6]
# sign: -1, y: -1.0, x: [1.  5.7 4.5]
# sign: -1, y: -1.0, x: [1.  6.3 4.7]
# sign: -1, y: -1.0, x: [1.  4.9 3.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.6]
# sign: -1, y: -1.0, x: [1.  5.2 3.9]
# sign: -1, y: -1.0, x: [1.  5.  3.5]
# sign: -1, y: -1.0, x: [1.  5.9 4.2]
# sign: -1, y: -1.0, x: [1. 6. 4.]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  5.6 3.6]
# sign: -1, y: -1.0, x: [1.  6.7 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.5]
# sign: -1, y: -1.0, x: [1.  5.8 4.1]
# sign: -1, y: -1.0, x: [1.  6.2 4.5]
# sign: -1, y: -1.0, x: [1.  5.6 3.9]
# sign: -1, y: -1.0, x: [1.  5.9 4.8]
# sign: -1, y: -1.0, x: [1.  6.1 4. ]
# sign: -1, y: -1.0, x: [1.  6.3 4.9]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  6.4 4.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.4]
# sign: -1, y: -1.0, x: [1.  6.8 4.8]
# sign: -1, y: -1.0, x: [1.  6.7 5. ]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: -1, y: -1.0, x: [1.  5.7 3.5]
# sign: -1, y: -1.0, x: [1.  5.5 3.8]
# sign: -1, y: -1.0, x: [1.  5.5 3.7]
# sign: -1, y: -1.0, x: [1.  5.8 3.9]
# sign: -1, y: -1.0, x: [1.  6.  5.1]
# sign: -1, y: -1.0, x: [1.  5.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: -1, y: -1.0, x: [1.  6.7 4.7]
# sign: -1, y: -1.0, x: [1.  6.3 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.1]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  5.5 4.4]
# sign: -1, y: -1.0, x: [1.  6.1 4.6]
# sign: -1, y: -1.0, x: [1.  5.8 4. ]
# sign: -1, y: -1.0, x: [1.  5.  3.3]
# sign: -1, y: -1.0, x: [1.  5.6 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  6.2 4.3]
# sign: -1, y: -1.0, x: [1.  5.1 3. ]
# sign: -1, y: -1.0, x: [1.  5.7 4.1]
# sign: -1, y: 1.0, x: [1.  5.1 1.4]
# iterator: 2
# x: [1.  5.1 1.4]
# w: [ 1.   3.2 -1.9]
# sign: 1, y: 1.0, x: [1.  4.9 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.3]
# sign: 1, y: 1.0, x: [1.  4.6 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.  1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  4.3 1.1]
# sign: 1, y: 1.0, x: [1.  5.8 1.2]
# sign: 1, y: 1.0, x: [1.  5.7 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.4]
# sign: 1, y: 1.0, x: [1.  5.7 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  4.6 1. ]
# sign: 1, y: 1.0, x: [1.  5.1 1.7]
# sign: 1, y: 1.0, x: [1.  4.8 1.9]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.5 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.2]
# sign: 1, y: 1.0, x: [1.  5.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.3]
# sign: 1, y: 1.0, x: [1.  4.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.1 1.9]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  5.1 1.6]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.3 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: 1, y: -1.0, x: [1.  7.  4.7]
# iterator: 3
# x: [1.  7.  4.7]
# w: [ 0.  -3.8 -6.6]
# sign: -1, y: -1.0, x: [1.  6.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.9 4.9]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  6.5 4.6]
# sign: -1, y: -1.0, x: [1.  5.7 4.5]
# sign: -1, y: -1.0, x: [1.  6.3 4.7]
# sign: -1, y: -1.0, x: [1.  4.9 3.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.6]
# sign: -1, y: -1.0, x: [1.  5.2 3.9]
# sign: -1, y: -1.0, x: [1.  5.  3.5]
# sign: -1, y: -1.0, x: [1.  5.9 4.2]
# sign: -1, y: -1.0, x: [1. 6. 4.]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  5.6 3.6]
# sign: -1, y: -1.0, x: [1.  6.7 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.5]
# sign: -1, y: -1.0, x: [1.  5.8 4.1]
# sign: -1, y: -1.0, x: [1.  6.2 4.5]
# sign: -1, y: -1.0, x: [1.  5.6 3.9]
# sign: -1, y: -1.0, x: [1.  5.9 4.8]
# sign: -1, y: -1.0, x: [1.  6.1 4. ]
# sign: -1, y: -1.0, x: [1.  6.3 4.9]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  6.4 4.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.4]
# sign: -1, y: -1.0, x: [1.  6.8 4.8]
# sign: -1, y: -1.0, x: [1.  6.7 5. ]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: -1, y: -1.0, x: [1.  5.7 3.5]
# sign: -1, y: -1.0, x: [1.  5.5 3.8]
# sign: -1, y: -1.0, x: [1.  5.5 3.7]
# sign: -1, y: -1.0, x: [1.  5.8 3.9]
# sign: -1, y: -1.0, x: [1.  6.  5.1]
# sign: -1, y: -1.0, x: [1.  5.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: -1, y: -1.0, x: [1.  6.7 4.7]
# sign: -1, y: -1.0, x: [1.  6.3 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.1]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  5.5 4.4]
# sign: -1, y: -1.0, x: [1.  6.1 4.6]
# sign: -1, y: -1.0, x: [1.  5.8 4. ]
# sign: -1, y: -1.0, x: [1.  5.  3.3]
# sign: -1, y: -1.0, x: [1.  5.6 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  6.2 4.3]
# sign: -1, y: -1.0, x: [1.  5.1 3. ]
# sign: -1, y: -1.0, x: [1.  5.7 4.1]
# sign: -1, y: 1.0, x: [1.  5.1 1.4]
# iterator: 4
# x: [1.  5.1 1.4]
# w: [ 1.   1.3 -5.2]
# sign: 1, y: 1.0, x: [1.  4.9 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.3]
# sign: -1, y: 1.0, x: [1.  4.6 1.5]
# iterator: 5
# x: [1.  4.6 1.5]
# w: [ 2.   5.9 -3.7]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.  1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  4.3 1.1]
# sign: 1, y: 1.0, x: [1.  5.8 1.2]
# sign: 1, y: 1.0, x: [1.  5.7 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.4]
# sign: 1, y: 1.0, x: [1.  5.7 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  4.6 1. ]
# sign: 1, y: 1.0, x: [1.  5.1 1.7]
# sign: 1, y: 1.0, x: [1.  4.8 1.9]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.5 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.2]
# sign: 1, y: 1.0, x: [1.  5.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.3]
# sign: 1, y: 1.0, x: [1.  4.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.1 1.9]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  5.1 1.6]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.3 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: 1, y: -1.0, x: [1.  7.  4.7]
# iterator: 6
# x: [1.  7.  4.7]
# w: [ 1.  -1.1 -8.4]
# sign: -1, y: -1.0, x: [1.  6.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.9 4.9]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  6.5 4.6]
# sign: -1, y: -1.0, x: [1.  5.7 4.5]
# sign: -1, y: -1.0, x: [1.  6.3 4.7]
# sign: -1, y: -1.0, x: [1.  4.9 3.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.6]
# sign: -1, y: -1.0, x: [1.  5.2 3.9]
# sign: -1, y: -1.0, x: [1.  5.  3.5]
# sign: -1, y: -1.0, x: [1.  5.9 4.2]
# sign: -1, y: -1.0, x: [1. 6. 4.]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  5.6 3.6]
# sign: -1, y: -1.0, x: [1.  6.7 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.5]
# sign: -1, y: -1.0, x: [1.  5.8 4.1]
# sign: -1, y: -1.0, x: [1.  6.2 4.5]
# sign: -1, y: -1.0, x: [1.  5.6 3.9]
# sign: -1, y: -1.0, x: [1.  5.9 4.8]
# sign: -1, y: -1.0, x: [1.  6.1 4. ]
# sign: -1, y: -1.0, x: [1.  6.3 4.9]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  6.4 4.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.4]
# sign: -1, y: -1.0, x: [1.  6.8 4.8]
# sign: -1, y: -1.0, x: [1.  6.7 5. ]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: -1, y: -1.0, x: [1.  5.7 3.5]
# sign: -1, y: -1.0, x: [1.  5.5 3.8]
# sign: -1, y: -1.0, x: [1.  5.5 3.7]
# sign: -1, y: -1.0, x: [1.  5.8 3.9]
# sign: -1, y: -1.0, x: [1.  6.  5.1]
# sign: -1, y: -1.0, x: [1.  5.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: -1, y: -1.0, x: [1.  6.7 4.7]
# sign: -1, y: -1.0, x: [1.  6.3 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.1]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  5.5 4.4]
# sign: -1, y: -1.0, x: [1.  6.1 4.6]
# sign: -1, y: -1.0, x: [1.  5.8 4. ]
# sign: -1, y: -1.0, x: [1.  5.  3.3]
# sign: -1, y: -1.0, x: [1.  5.6 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  6.2 4.3]
# sign: -1, y: -1.0, x: [1.  5.1 3. ]
# sign: -1, y: -1.0, x: [1.  5.7 4.1]
# sign: -1, y: 1.0, x: [1.  5.1 1.4]
# iterator: 7
# x: [1.  5.1 1.4]
# w: [ 2.  4. -7.]
# sign: 1, y: 1.0, x: [1.  4.9 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.3]
# sign: 1, y: 1.0, x: [1.  4.6 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.  1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  4.3 1.1]
# sign: 1, y: 1.0, x: [1.  5.8 1.2]
# sign: 1, y: 1.0, x: [1.  5.7 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.4]
# sign: 1, y: 1.0, x: [1.  5.7 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  4.6 1. ]
# sign: 1, y: 1.0, x: [1.  5.1 1.7]
# sign: 1, y: 1.0, x: [1.  4.8 1.9]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.5 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.2]
# sign: 1, y: 1.0, x: [1.  5.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.3]
# sign: 1, y: 1.0, x: [1.  4.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.1 1.9]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  5.1 1.6]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.3 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: -1, y: -1.0, x: [1.  7.  4.7]
# sign: -1, y: -1.0, x: [1.  6.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.9 4.9]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  6.5 4.6]
# sign: -1, y: -1.0, x: [1.  5.7 4.5]
# sign: -1, y: -1.0, x: [1.  6.3 4.7]
# sign: -1, y: -1.0, x: [1.  4.9 3.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.6]
# sign: -1, y: -1.0, x: [1.  5.2 3.9]
# sign: -1, y: -1.0, x: [1.  5.  3.5]
# sign: -1, y: -1.0, x: [1.  5.9 4.2]
# sign: -1, y: -1.0, x: [1. 6. 4.]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  5.6 3.6]
# sign: -1, y: -1.0, x: [1.  6.7 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.5]
# sign: -1, y: -1.0, x: [1.  5.8 4.1]
# sign: -1, y: -1.0, x: [1.  6.2 4.5]
# sign: -1, y: -1.0, x: [1.  5.6 3.9]
# sign: -1, y: -1.0, x: [1.  5.9 4.8]
# sign: -1, y: -1.0, x: [1.  6.1 4. ]
# sign: -1, y: -1.0, x: [1.  6.3 4.9]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  6.4 4.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.4]
# sign: -1, y: -1.0, x: [1.  6.8 4.8]
# sign: -1, y: -1.0, x: [1.  6.7 5. ]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: 1, y: -1.0, x: [1.  5.7 3.5]
# iterator: 8
# x: [1.  5.7 3.5]
# w: [  1.   -1.7 -10.5]
# sign: -1, y: -1.0, x: [1.  5.5 3.8]
# sign: -1, y: -1.0, x: [1.  5.5 3.7]
# sign: -1, y: -1.0, x: [1.  5.8 3.9]
# sign: -1, y: -1.0, x: [1.  6.  5.1]
# sign: -1, y: -1.0, x: [1.  5.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: -1, y: -1.0, x: [1.  6.7 4.7]
# sign: -1, y: -1.0, x: [1.  6.3 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.1]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  5.5 4.4]
# sign: -1, y: -1.0, x: [1.  6.1 4.6]
# sign: -1, y: -1.0, x: [1.  5.8 4. ]
# sign: -1, y: -1.0, x: [1.  5.  3.3]
# sign: -1, y: -1.0, x: [1.  5.6 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  6.2 4.3]
# sign: -1, y: -1.0, x: [1.  5.1 3. ]
# sign: -1, y: -1.0, x: [1.  5.7 4.1]
# sign: -1, y: 1.0, x: [1.  5.1 1.4]
# iterator: 9
# x: [1.  5.1 1.4]
# w: [ 2.   3.4 -9.1]
# sign: 1, y: 1.0, x: [1.  4.9 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.3]
# sign: 1, y: 1.0, x: [1.  4.6 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.  1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  4.3 1.1]
# sign: 1, y: 1.0, x: [1.  5.8 1.2]
# sign: 1, y: 1.0, x: [1.  5.7 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.4]
# sign: 1, y: 1.0, x: [1.  5.7 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  4.6 1. ]
# sign: 1, y: 1.0, x: [1.  5.1 1.7]
# sign: 1, y: 1.0, x: [1.  4.8 1.9]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.5 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.2]
# sign: 1, y: 1.0, x: [1.  5.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.3]
# sign: 1, y: 1.0, x: [1.  4.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.1 1.9]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  5.1 1.6]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.3 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: -1, y: -1.0, x: [1.  7.  4.7]
# sign: -1, y: -1.0, x: [1.  6.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.9 4.9]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  6.5 4.6]
# sign: -1, y: -1.0, x: [1.  5.7 4.5]
# sign: -1, y: -1.0, x: [1.  6.3 4.7]
# sign: -1, y: -1.0, x: [1.  4.9 3.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.6]
# sign: -1, y: -1.0, x: [1.  5.2 3.9]
# sign: -1, y: -1.0, x: [1.  5.  3.5]
# sign: -1, y: -1.0, x: [1.  5.9 4.2]
# sign: -1, y: -1.0, x: [1. 6. 4.]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  5.6 3.6]
# sign: -1, y: -1.0, x: [1.  6.7 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.5]
# sign: -1, y: -1.0, x: [1.  5.8 4.1]
# sign: -1, y: -1.0, x: [1.  6.2 4.5]
# sign: -1, y: -1.0, x: [1.  5.6 3.9]
# sign: -1, y: -1.0, x: [1.  5.9 4.8]
# sign: -1, y: -1.0, x: [1.  6.1 4. ]
# sign: -1, y: -1.0, x: [1.  6.3 4.9]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  6.4 4.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.4]
# sign: -1, y: -1.0, x: [1.  6.8 4.8]
# sign: -1, y: -1.0, x: [1.  6.7 5. ]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: -1, y: -1.0, x: [1.  5.7 3.5]
# sign: -1, y: -1.0, x: [1.  5.5 3.8]
# sign: -1, y: -1.0, x: [1.  5.5 3.7]
# sign: -1, y: -1.0, x: [1.  5.8 3.9]
# sign: -1, y: -1.0, x: [1.  6.  5.1]
# sign: -1, y: -1.0, x: [1.  5.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: -1, y: -1.0, x: [1.  6.7 4.7]
# sign: -1, y: -1.0, x: [1.  6.3 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.1]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  5.5 4.4]
# sign: -1, y: -1.0, x: [1.  6.1 4.6]
# sign: -1, y: -1.0, x: [1.  5.8 4. ]
# sign: -1, y: -1.0, x: [1.  5.  3.3]
# sign: -1, y: -1.0, x: [1.  5.6 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  6.2 4.3]
# sign: -1, y: -1.0, x: [1.  5.1 3. ]
# sign: -1, y: -1.0, x: [1.  5.7 4.1]
# sign: 1, y: 1.0, x: [1.  5.1 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.3]
# sign: 1, y: 1.0, x: [1.  4.6 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.  1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  4.3 1.1]
# sign: 1, y: 1.0, x: [1.  5.8 1.2]
# sign: 1, y: 1.0, x: [1.  5.7 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.4]
# sign: 1, y: 1.0, x: [1.  5.7 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.4 1.7]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  4.6 1. ]
# sign: 1, y: 1.0, x: [1.  5.1 1.7]
# sign: 1, y: 1.0, x: [1.  4.8 1.9]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.4]
# sign: 1, y: 1.0, x: [1.  4.7 1.6]
# sign: 1, y: 1.0, x: [1.  4.8 1.6]
# sign: 1, y: 1.0, x: [1.  5.4 1.5]
# sign: 1, y: 1.0, x: [1.  5.2 1.5]
# sign: 1, y: 1.0, x: [1.  5.5 1.4]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.2]
# sign: 1, y: 1.0, x: [1.  5.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.9 1.5]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.1 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.3]
# sign: 1, y: 1.0, x: [1.  4.5 1.3]
# sign: 1, y: 1.0, x: [1.  4.4 1.3]
# sign: 1, y: 1.0, x: [1.  5.  1.6]
# sign: 1, y: 1.0, x: [1.  5.1 1.9]
# sign: 1, y: 1.0, x: [1.  4.8 1.4]
# sign: 1, y: 1.0, x: [1.  5.1 1.6]
# sign: 1, y: 1.0, x: [1.  4.6 1.4]
# sign: 1, y: 1.0, x: [1.  5.3 1.5]
# sign: 1, y: 1.0, x: [1.  5.  1.4]
# sign: -1, y: -1.0, x: [1.  7.  4.7]
# sign: -1, y: -1.0, x: [1.  6.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.9 4.9]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  6.5 4.6]
# sign: -1, y: -1.0, x: [1.  5.7 4.5]
# sign: -1, y: -1.0, x: [1.  6.3 4.7]
# sign: -1, y: -1.0, x: [1.  4.9 3.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.6]
# sign: -1, y: -1.0, x: [1.  5.2 3.9]
# sign: -1, y: -1.0, x: [1.  5.  3.5]
# sign: -1, y: -1.0, x: [1.  5.9 4.2]
# sign: -1, y: -1.0, x: [1. 6. 4.]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  5.6 3.6]
# sign: -1, y: -1.0, x: [1.  6.7 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.5]
# sign: -1, y: -1.0, x: [1.  5.8 4.1]
# sign: -1, y: -1.0, x: [1.  6.2 4.5]
# sign: -1, y: -1.0, x: [1.  5.6 3.9]
# sign: -1, y: -1.0, x: [1.  5.9 4.8]
# sign: -1, y: -1.0, x: [1.  6.1 4. ]
# sign: -1, y: -1.0, x: [1.  6.3 4.9]
# sign: -1, y: -1.0, x: [1.  6.1 4.7]
# sign: -1, y: -1.0, x: [1.  6.4 4.3]
# sign: -1, y: -1.0, x: [1.  6.6 4.4]
# sign: -1, y: -1.0, x: [1.  6.8 4.8]
# sign: -1, y: -1.0, x: [1.  6.7 5. ]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: -1, y: -1.0, x: [1.  5.7 3.5]
# sign: -1, y: -1.0, x: [1.  5.5 3.8]
# sign: -1, y: -1.0, x: [1.  5.5 3.7]
# sign: -1, y: -1.0, x: [1.  5.8 3.9]
# sign: -1, y: -1.0, x: [1.  6.  5.1]
# sign: -1, y: -1.0, x: [1.  5.4 4.5]
# sign: -1, y: -1.0, x: [1.  6.  4.5]
# sign: -1, y: -1.0, x: [1.  6.7 4.7]
# sign: -1, y: -1.0, x: [1.  6.3 4.4]
# sign: -1, y: -1.0, x: [1.  5.6 4.1]
# sign: -1, y: -1.0, x: [1.  5.5 4. ]
# sign: -1, y: -1.0, x: [1.  5.5 4.4]
# sign: -1, y: -1.0, x: [1.  6.1 4.6]
# sign: -1, y: -1.0, x: [1.  5.8 4. ]
# sign: -1, y: -1.0, x: [1.  5.  3.3]
# sign: -1, y: -1.0, x: [1.  5.6 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  5.7 4.2]
# sign: -1, y: -1.0, x: [1.  6.2 4.3]
# sign: -1, y: -1.0, x: [1.  5.1 3. ]
# sign: -1, y: -1.0, x: [1.  5.7 4.1]
